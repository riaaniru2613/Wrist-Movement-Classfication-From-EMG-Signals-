# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
# Establishing the current work directory (cwd)
dir_path = '/content/drive/MyDrive/Major Project/Features Dataset'

# File_Names = []
# for (dir_path, dir_names, file_names) in os.walk(dir_path):
#     File_Names.extend(file_names)    
# print("Total files read is ", len(File_Names))

Files = []
for r, d, f in os.walk(dir_path):
    for file in f:
        if ".csv" in file:
            Files.append(os.path.join(r, file))
# filenames1 = Files[1:]
filenames = Files

# %%
frames = []
for file in filenames:  

  # print(file)
  file_data = pd.read_csv(file)
  # display(file_data)
  frames.append(file_data)

Data = pd.concat(frames, ignore_index = True)
print("Size of all the feature matrix combined is ", Data.shape)
# Out:
# Size of all the feature matrix combined is  (10800, 19)

# %%
# display(Data[0])

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaler.fit(Data)
# print(Data)

from sklearn.preprocessing import Normalizer
sc = Normalizer()
sc.fit_transform(Data)
# Out:
# array([[2.64494368e-12, 1.48931974e-07, 6.24540148e-05, ...,
#         3.16410998e-01, 8.38842953e-03, 1.62002431e-02],
#        [1.83269920e-12, 9.76848185e-08, 4.00108776e-05, ...,
#         6.09618578e-01, 6.57426557e-03, 1.04041571e-02],
#        [3.99438777e-12, 1.60661658e-07, 6.32697589e-05, ...,
#         4.03403225e-01, 8.08305223e-03, 1.29089032e-02],
#        ...,
#        [8.05934915e-13, 8.33018948e-08, 3.19148061e-05, ...,
#         4.03365233e-01, 8.02504760e-03, 5.16307499e-02],
#        [2.02261513e-13, 3.44926377e-08, 1.33725400e-05, ...,
#         3.64483148e-01, 8.63932106e-03, 3.49903822e-02],
#        [2.23798599e-13, 4.16708263e-08, 1.56388710e-05, ...,
#         4.20245590e-01, 9.51588836e-03, 4.61069447e-02]])

# %%
labels = np.array(Data['Output'])
# print(Data['Output'].value_counts())

Data= Data.drop('Output', axis = 1)

feature_list = list(Data.columns)

Data = np.array(Data)

# %%
train_features, test_features, train_labels, test_labels = train_test_split(Data, labels, test_size = 0.2,stratify = labels)

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# train_labels = le.fit_transform(train_labels)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (8640, 18)
# Training Labels Shape: (8640,)
# Testing Features Shape: (2160, 18)
# Testing Labels Shape: (2160,)

# %%
# from numpy import loadtxt
# from xgboost import XGBClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score

# %%
# model = XGBClassifier()
# model.fit(train_features, train_labels)
# print(model)

# %%
# y_pred = model.predict(test_features)
# predictions = [round(value) for value in y_pred]
# # evaluate predictions
# accuracy = accuracy_score(test_labels, predictions)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
# from sklearn.tree import DecisionTreeClassifier

# DT = DecisionTreeClassifier()
# DT.fit(train_features, train_labels)

# %%
# from sklearn.naive_bayes import GaussianNB
# NB = GaussianNB()

# NB.fit(train_features, train_labels)

# %%
RF = RandomForestClassifier(n_estimators = 1000)
RF.fit(train_features, train_labels);

# %%
predictions = RF.predict(test_features)

errors = abs(predictions - test_labels)

print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 1.14 degrees.

# %%
mape = 100 * (errors / test_labels)

accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 58.23 %.
